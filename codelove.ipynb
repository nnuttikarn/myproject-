# %% [markdown]
# <a href="https://colab.research.google.com/github/nnuttikarn/myproject-/blob/main/codelove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install colabturtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for colabturtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=c99b06b1ea9847a54bfb2896a5c53769fafd4bda7d6b025ebb5eaffdb337e00c
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built colabturtle
# ...

# %%
from os import GRND_RANDOM
import ColabTurtle.Turtle as graph
def curve():
    for i in range(200):
      graph.left(1)
      graph.forward(1)

graph.initializeTurtle(initial_speed=10)
graph.bgcolor(139,211,230)
graph.color("red")
graph.right(45)
graph.forward(113)
curve()
graph.right(120)
curve()
graph.forward(112)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="rgb(139,211,230)"/>
# ...
